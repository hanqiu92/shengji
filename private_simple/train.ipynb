# %%
import numpy as np
import time
import matplotlib.pyplot as plt
# %matplotlib inline

from env import *
from states import *
from agents import *
from models import *
from util import *
# Out:
# /Users/hanqiu/anaconda3/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /Users/hanqiu/anaconda3/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /Users/hanqiu/anaconda3/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /Users/hanqiu/anaconda3/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:529: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /Users/hanqiu/anaconda3/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:530: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /Users/hanqiu/anaconda3/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:535: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
deck_size = len(Game().decks)

# %% [raw]
# generate_compress_games(1000,StateExtend,save_fname='dataset/valid_set_q.p')

# %% [markdown]
# ### Training Pipeline

# %%
## function to benchmark the learnt agents
def compare_agents(a_base,a_ai_1,a_ai_2,N_iter_loops=100,N_iter_games=100,state_generator=StateExtendV2,
                   compare_first_base_flag=False,compare_second_base_flag=False,compare_both_flag=True):
    cases = []
    if compare_first_base_flag:
        cases += [[a_ai_1,a_base,a_ai_1,a_base],
                  [a_base,a_ai_1,a_base,a_ai_1]]
    if compare_second_base_flag:
        cases += [[a_ai_2,a_base,a_ai_2,a_base],
                  [a_base,a_ai_2,a_base,a_ai_2]]
    if compare_both_flag:
        cases += [[a_ai_2,a_ai_1,a_ai_2,a_ai_1],
                  [a_ai_1,a_ai_2,a_ai_1,a_ai_2]]

    ttt = time.time()
    eval_results_all = []
    for _ in range(N_iter_loops):
        eval_results = []
        for agents in cases:
            curr_scores,eval_scores = \
                run_games(N_iter=N_iter_games,agents=agents,if_random_game=False,
                          fname='dataset/valid_set_q.p',state_generator=state_generator)
            eval_results.append(np.mean(eval_scores))
        eval_results = np.array(eval_results).reshape((-1,2))
        eval_results_all.append(eval_results)
    eval_results_all = np.stack(eval_results_all,axis=0)
    eval_mean = np.mean(eval_results_all,axis=0)
    eval_std = np.std(eval_results_all,axis=0)
    return 'time: {:.2f}. eval results: mean={}, std={}.'.format(
                time.time()-ttt,eval_mean.round(2),eval_std.round(2))

# %% [markdown]
# #### DQN

# %%
def load_q_agent(header,iter_,infer_flag=True):
    q_model = QModel(save_dir='model/',deck_size=deck_size)
    q_model.partial_restore('{}/{}'.format(header,iter_))
    agent = RlAgent(q_model)
    agent.infer_flag = infer_flag
    agent.sample_collect_flag = False
    return agent

# %%
version = 1
header = 'dqn-v{}'.format(version)

# %%
## initialize model
q_model = QModel(save_dir='model/',deck_size=deck_size)
q_model.learn_iter = 1
curr_iter = 0
q_model.save('{}/{}'.format(header,curr_iter))
q_model.restore('{}/{}'.format(header,curr_iter))
# Out:
# WARNING:tensorflow:From /Users/hanqiu/anaconda3/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /Users/hanqiu/anaconda3/lib/python3.6/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# WARNING:tensorflow:From /Users/hanqiu/anaconda3/lib/python3.6/site-packages/tensorflow/python/ops/math_grad.py:102: div (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Deprecated in favor of operator or tf.math.divide.
# WARNING:tensorflow:From /Users/hanqiu/anaconda3/lib/python3.6/site-packages/tensorflow/python/training/saver.py:1266: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to check for files with this prefix.
# INFO:tensorflow:Restoring parameters from model/dqn-v1/0/model

# %%
## train model using DQN
agents = []
for _ in range(4):
    agent = RlAgent(q_model)
    agent.sample_collect_flag = True
    agents.append(agent)

tt = time.time()
N_iter_inner = 10000
eval_freq = 1
for iter_outer in range(5):
    run_games(N_iter=N_iter_inner,agents=agents,if_train=True,models=[q_model],state_generator=StateExtend)
    q_model.save('dqn-v{}/{}'.format(version,curr_iter+(iter_outer+1)*N_iter_inner))
    q_model.partial_restore('dqn-v{}/{}'.format(version,curr_iter+(iter_outer+1)*N_iter_inner))
    print('{}:{:.2f}'.format(iter_outer+1,time.time() - tt))
    
    if (iter_outer+1) % eval_freq == 0 and iter_outer > 0:
        ## do some evaluation
        a_ai_1 = load_q_agent(header,curr_iter+(iter_outer+1-eval_freq)*N_iter_inner)
        a_ai_2 = load_q_agent(header,curr_iter+(iter_outer+1)*N_iter_inner)
        a_base = Agent()
        
        out_str = compare_agents(a_base,a_ai_1,a_ai_2,N_iter_loops=100,N_iter_games=100,
                    compare_first_base_flag=True,compare_both_flag=True)
        print('{}, {}'.format(iter_outer,out_str))
# Out:
# INFO:tensorflow:Restoring parameters from model/dqn-v1/10000/model
# 1:2713.14
# INFO:tensorflow:Restoring parameters from model/dqn-v1/20000/model
# 2:5512.90
# INFO:tensorflow:Restoring parameters from model/dqn-v1/10000/model
# INFO:tensorflow:Restoring parameters from model/dqn-v1/20000/model
# 1, time: 680.59. eval results: [[ 19.6 -35.8]
#  [-15.1  -8.8]].
# INFO:tensorflow:Restoring parameters from model/dqn-v1/30000/model
# 3:8993.65
# INFO:tensorflow:Restoring parameters from model/dqn-v1/20000/model
# INFO:tensorflow:Restoring parameters from model/dqn-v1/30000/model
# 2, time: 692.78. eval results: [[ 33.6 -37.8]
#  [ -6.3  -7.9]].
# INFO:tensorflow:Restoring parameters from model/dqn-v1/40000/model
# 4:12487.96
# INFO:tensorflow:Restoring parameters from model/dqn-v1/30000/model
# INFO:tensorflow:Restoring parameters from model/dqn-v1/40000/model
# 3, time: 696.97. eval results: [[ 26.2 -37.4]
#  [-11.9  -4.1]].
# INFO:tensorflow:Restoring parameters from model/dqn-v1/50000/model
# 5:16037.00
# INFO:tensorflow:Restoring parameters from model/dqn-v1/40000/model
# INFO:tensorflow:Restoring parameters from model/dqn-v1/50000/model
# 4, time: 708.04. eval results: [[  9.7 -34.2]
#  [ -7.6  -9.4]].

# %%
## do some final evaluation
a_ai_1 = load_q_agent(header,0)
a_ai_2 = load_q_agent(header,50000)
a_base = Agent()

out_str = compare_agents(a_base,a_ai_1,a_ai_2,N_iter_loops=100,N_iter_games=100,compare_both_flag=True)
print(out_str)
# Out:
# WARNING:tensorflow:From /Users/hanqiu/anaconda3/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /Users/hanqiu/anaconda3/lib/python3.6/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# WARNING:tensorflow:From /Users/hanqiu/anaconda3/lib/python3.6/site-packages/tensorflow/python/ops/math_grad.py:102: div (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Deprecated in favor of operator or tf.math.divide.
# WARNING:tensorflow:From /Users/hanqiu/anaconda3/lib/python3.6/site-packages/tensorflow/python/training/saver.py:1266: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to check for files with this prefix.
# INFO:tensorflow:Restoring parameters from model/dqn-v1/0/model
# INFO:tensorflow:Restoring parameters from model/dqn-v1/50000/model
# time: 495.63. eval results: mean=[[ 15.44 -32.92]], std=[[6.72 4.7 ]].

# %% [markdown]
# #### CFR

# %%
## useful utility functions
def init_cfr_models(learn_iter,header,curr_iter=0):
    regret_models = []
    for p_ in range(4):
        regret_model = CFRModel(save_dir='model/',deck_size=deck_size)
        regret_model.learn_iter = learn_iter
        regret_model.train_target_flag = 'r'
        regret_models.append(regret_model)
    policy_model = CFRModel(save_dir='model/',deck_size=deck_size)
    policy_model.learn_iter = learn_iter * 4
    policy_model.train_target_flag = 'p'
    baseline_model = CFRBaselineModel(save_dir='model/',deck_size=deck_size)
    baseline_model.learn_iter = learn_iter
    save_cfr_models(regret_models,policy_model,baseline_model,header,iter_=curr_iter)
    return regret_models,policy_model,baseline_model

def save_cfr_models(regret_models,policy_model,baseline_model,header,iter_):
    for p_ in range(4):
        regret_models[p_].save('{}/r{}-{}'.format(header,p_,iter_))
    policy_model.save('{}/p-{}'.format(header,iter_))
    baseline_model.save('{}/b-{}'.format(header,iter_))

def load_cfr_models(header,iter_):
    regret_models = []
    for p_ in range(4):
        regret_model = CFRModel(save_dir='model/',deck_size=deck_size)
        regret_model.partial_restore('{}/r{}-{}'.format(header,p_,iter_))
        regret_models.append(regret_model)
    policy_model = CFRModel(save_dir='model/',deck_size=deck_size)
    policy_model.partial_restore('{}/p-{}'.format(header,iter_))
    baseline_model = CFRBaselineModel(save_dir='model/',deck_size=deck_size)
    baseline_model.partial_restore('{}/b-{}'.format(header,iter_))
    return regret_models,policy_model,baseline_model

def load_cfr_agent(header,iter_,infer_flag=True):
    regret_models,policy_model,baseline_model = \
            load_cfr_models(header,iter_)
    agent = CFRAgent(regret_models,policy_model)
    agent.infer_flag = infer_flag
    agent.sample_collect_flag = False
    return agent

# %%
version = 1
header = 'cfr-v{}'.format(version)

# %%
## initialize model
N_iter_train = 500
curr_iter = 0
regret_models,policy_model,baseline_model = init_cfr_models(N_iter_train,header,curr_iter)

# %%
## train model using CFR
e_sim = Env(Game(),DefaultPlayer(),state_generator=StateExtendV2)
explore_alpha = 0.1
agents = []
for p_ in range(4):
#     agent = CFRAgent(regret_models,policy_model,explore_alpha=explore_alpha,explore_player=p_)
#     agent = CFRRolloutAgent(regret_models,policy_model,e_sim,explore_alpha=explore_alpha,explore_player=p_)
#     agent = CFRExternalAgent(regret_models,policy_model,e_sim,explore_alpha=explore_alpha,explore_player=p_)
    agent = CFRBaselineAgent(regret_models,policy_model,baseline_model,
                             explore_alpha=explore_alpha,explore_player=p_)
    agent.infer_flag = False
    agents.append(agent)

tt = time.time()
N_iter_inner = 100
eval_freq = 1
for iter_outer in range(20):
    for agent in agents:
        agent.update_train_meta()
        
    for p_ in range(4):
        for agent in agents:
            agent.sample_collect_flag = False
        agents[p_].sample_collect_flag = True
        
        run_games(N_iter=N_iter_inner,agents=agents,if_train=False,
                  models=regret_models,state_generator=StateExtendV2)
        
        regret_models[p_].learn()
        baseline_model.learn()
        
    policy_model.learn()
    
    save_cfr_models(regret_models,policy_model,baseline_model,header,curr_iter+(iter_outer+1)*N_iter_inner)
    print('{}:{:.2f}'.format(iter_outer+1,time.time() - tt))
    
    if (iter_outer+1) % eval_freq == 0 and iter_outer > 0:
        ## do some evaluation
        a_ai_1 = load_cfr_agent(header,curr_iter+(iter_outer+1-eval_freq)*N_iter_inner)
        a_ai_2 = load_cfr_agent(header,curr_iter+(iter_outer+1)*N_iter_inner)
        a_base = Agent()
        
        out_str = compare_agents(a_base,a_ai_1,a_ai_2,N_iter_loops=100,N_iter_games=100,
                    compare_first_base_flag=True,compare_both_flag=True)
        print('{}, {}'.format(iter_outer,out_str))
# Out:
# 1:222.84
# 2:1813.69
# WARNING:tensorflow:From /Users/hanqiu/anaconda3/lib/python3.6/site-packages/tensorflow/python/training/saver.py:1266: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to check for files with this prefix.
# INFO:tensorflow:Restoring parameters from model/cfr-v1/r0-100/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/r1-100/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/r2-100/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/r3-100/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/p-100/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/b-100/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/r0-200/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/r1-200/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/r2-200/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/r3-200/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/p-200/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/b-200/model
# 1, time: 1249.13. eval results: mean=[[-6.7  -5.46]
#  [-6.75 -6.54]], std=[[7.51 7.29]
#  [6.66 6.8 ]].
# 3:4916.07
# INFO:tensorflow:Restoring parameters from model/cfr-v1/r0-200/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/r1-200/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/r2-200/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/r3-200/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/p-200/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/b-200/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/r0-300/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/r1-300/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/r2-300/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/r3-300/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/p-300/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/b-300/model
# 2, time: 1261.81. eval results: mean=[[-5.85 -5.56]
#  [-7.92 -6.33]], std=[[7.1  7.32]
#  [7.2  6.8 ]].
# 4:7707.10
# INFO:tensorflow:Restoring parameters from model/cfr-v1/r0-300/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/r1-300/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/r2-300/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/r3-300/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/p-300/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/b-300/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/r0-400/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/r1-400/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/r2-400/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/r3-400/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/p-400/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/b-400/model
# 3, time: 1263.98. eval results: mean=[[-5.9  -5.59]
#  [-6.35 -4.47]], std=[[7.26 7.26]
#  [7.25 6.62]].
# 5:11714.75
# INFO:tensorflow:Restoring parameters from model/cfr-v1/r0-400/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/r1-400/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/r2-400/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/r3-400/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/p-400/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/b-400/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/r0-500/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/r1-500/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/r2-500/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/r3-500/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/p-500/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/b-500/model
# 4, time: 1265.78. eval results: mean=[[-6.83 -4.18]
#  [-7.   -5.7 ]], std=[[7.62 6.82]
#  [6.58 6.4 ]].
# 6:16007.64
# INFO:tensorflow:Restoring parameters from model/cfr-v1/r0-500/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/r1-500/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/r2-500/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/r3-500/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/p-500/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/b-500/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/r0-600/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/r1-600/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/r2-600/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/r3-600/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/p-600/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/b-600/model
# 5, time: 1273.82. eval results: mean=[[-7.5  -5.37]
#  [-4.91 -5.57]], std=[[7.08 7.44]
#  [7.45 7.37]].
# 7:20053.82
# INFO:tensorflow:Restoring parameters from model/cfr-v1/r0-600/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/r1-600/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/r2-600/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/r3-600/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/p-600/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/b-600/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/r0-700/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/r1-700/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/r2-700/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/r3-700/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/p-700/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/b-700/model
# 6, time: 1270.44. eval results: mean=[[-6.36 -2.95]
#  [-6.76 -1.96]], std=[[7.14 7.5 ]
#  [7.1  7.09]].
# 8:24371.67
# INFO:tensorflow:Restoring parameters from model/cfr-v1/r0-700/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/r1-700/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/r2-700/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/r3-700/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/p-700/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/b-700/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/r0-800/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/r1-800/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/r2-800/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/r3-800/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/p-800/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/b-800/model
# 7, time: 1289.52. eval results: mean=[[-6.39 -3.39]
#  [-4.4  -3.95]], std=[[7.55 7.47]
#  [6.88 6.73]].
# 9:28434.72
# INFO:tensorflow:Restoring parameters from model/cfr-v1/r0-800/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/r1-800/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/r2-800/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/r3-800/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/p-800/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/b-800/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/r0-900/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/r1-900/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/r2-900/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/r3-900/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/p-900/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/b-900/model
# 8, time: 1322.19. eval results: mean=[[-7.22 -2.1 ]
#  [-2.66 -1.56]], std=[[7.86 6.9 ]
#  [7.43 6.99]].
# 10:32821.42
# INFO:tensorflow:Restoring parameters from model/cfr-v1/r0-900/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/r1-900/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/r2-900/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/r3-900/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/p-900/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/b-900/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/r0-1000/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/r1-1000/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/r2-1000/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/r3-1000/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/p-1000/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/b-1000/model
# 9, time: 1279.81. eval results: mean=[[-8.39 -1.52]
#  [-3.18 -1.76]], std=[[7.41 7.72]
#  [7.43 6.46]].
# 11:42221.27
# INFO:tensorflow:Restoring parameters from model/cfr-v1/r0-1000/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/r1-1000/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/r2-1000/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/r3-1000/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/p-1000/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/b-1000/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/r0-1100/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/r1-1100/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/r2-1100/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/r3-1100/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/p-1100/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/b-1100/model
# 10, time: 1286.31. eval results: mean=[[-7.18 -3.7 ]
#  [-3.83 -4.11]], std=[[7.79 6.7 ]
#  [7.53 7.56]].
# 12:46314.70
# INFO:tensorflow:Restoring parameters from model/cfr-v1/r0-1100/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/r1-1100/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/r2-1100/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/r3-1100/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/p-1100/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/b-1100/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/r0-1200/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/r1-1200/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/r2-1200/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/r3-1200/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/p-1200/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/b-1200/model
# 11, time: 1277.05. eval results: mean=[[-6.43 -2.51]
#  [-2.77 -3.27]], std=[[7.58 7.17]
#  [7.58 7.08]].
# 13:50677.15
# INFO:tensorflow:Restoring parameters from model/cfr-v1/r0-1200/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/r1-1200/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/r2-1200/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/r3-1200/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/p-1200/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/b-1200/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/r0-1300/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/r1-1300/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/r2-1300/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/r3-1300/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/p-1300/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/b-1300/model
# 12, time: 1268.11. eval results: mean=[[-6.03 -2.43]
#  [ 0.42 -3.7 ]], std=[[8.05 6.85]
#  [6.67 6.62]].
# 14:59697.12
# INFO:tensorflow:Restoring parameters from model/cfr-v1/r0-1300/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/r1-1300/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/r2-1300/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/r3-1300/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/p-1300/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/b-1300/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/r0-1400/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/r1-1400/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/r2-1400/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/r3-1400/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/p-1400/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/b-1400/model
# 13, time: 1285.94. eval results: mean=[[-6.68 -5.24]
#  [-6.85 -0.41]], std=[[7.67 6.91]
#  [7.36 7.32]].
# 15:63736.03
# INFO:tensorflow:Restoring parameters from model/cfr-v1/r0-1400/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/r1-1400/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/r2-1400/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/r3-1400/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/p-1400/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/b-1400/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/r0-1500/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/r1-1500/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/r2-1500/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/r3-1500/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/p-1500/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/b-1500/model
# 14, time: 1293.94. eval results: mean=[[-6.72 -1.92]
#  [-3.97 -2.32]], std=[[8.08 7.6 ]
#  [6.8  7.88]].
# 16:68064.83
# INFO:tensorflow:Restoring parameters from model/cfr-v1/r0-1500/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/r1-1500/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/r2-1500/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/r3-1500/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/p-1500/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/b-1500/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/r0-1600/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/r1-1600/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/r2-1600/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/r3-1600/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/p-1600/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/b-1600/model
# 15, time: 1288.15. eval results: mean=[[-5.87 -2.08]
#  [-1.47 -3.54]], std=[[6.33 6.92]
#  [7.45 7.96]].
# 17:72108.84
# INFO:tensorflow:Restoring parameters from model/cfr-v1/r0-1600/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/r1-1600/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/r2-1600/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/r3-1600/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/p-1600/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/b-1600/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/r0-1700/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/r1-1700/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/r2-1700/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/r3-1700/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/p-1700/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/b-1700/model
# 16, time: 1285.24. eval results: mean=[[-7.35 -4.6 ]
#  [-4.33 -6.46]], std=[[6.87 7.39]
#  [7.89 6.79]].
# 18:76415.20
# INFO:tensorflow:Restoring parameters from model/cfr-v1/r0-1700/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/r1-1700/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/r2-1700/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/r3-1700/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/p-1700/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/b-1700/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/r0-1800/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/r1-1800/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/r2-1800/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/r3-1800/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/p-1800/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/b-1800/model
# 17, time: 1289.13. eval results: mean=[[-7.22 -7.21]
#  [-6.45 -7.12]], std=[[7.97 7.03]
#  [6.34 8.29]].
# 19:80439.58
# INFO:tensorflow:Restoring parameters from model/cfr-v1/r0-1800/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/r1-1800/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/r2-1800/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/r3-1800/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/p-1800/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/b-1800/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/r0-1900/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/r1-1900/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/r2-1900/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/r3-1900/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/p-1900/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/b-1900/model
# 18, time: 1315.90. eval results: mean=[[-7.65 -6.56]
#  [-5.81 -6.18]], std=[[6.95 7.48]
#  [8.44 7.08]].
# 20:85090.47
# INFO:tensorflow:Restoring parameters from model/cfr-v1/r0-1900/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/r1-1900/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/r2-1900/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/r3-1900/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/p-1900/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/b-1900/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/r0-2000/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/r1-2000/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/r2-2000/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/r3-2000/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/p-2000/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/b-2000/model
# 19, time: 1271.32. eval results: mean=[[-7.38 -6.69]
#  [-8.14 -3.65]], std=[[7.84 7.3 ]
#  [7.4  6.95]].

# %%
## do some final evaluation
infer_flag = False
a_ai_1 = load_cfr_agent(header,0,infer_flag)
a_ai_2 = load_cfr_agent(header,2000,infer_flag)
a_base = Agent()

out_str = compare_agents(a_base,a_ai_1,a_ai_2,N_iter_loops=100,N_iter_games=100,compare_both_flag=True)
print(out_str)
# Out:
# INFO:tensorflow:Restoring parameters from model/cfr-v1/r0-0/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/r1-0/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/r2-0/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/r3-0/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/p-0/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/b-0/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/r0-2000/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/r1-2000/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/r2-2000/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/r3-2000/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/p-2000/model
# INFO:tensorflow:Restoring parameters from model/cfr-v1/b-2000/model
# time: 491.76. eval results: mean=[[-2.8  -6.08]], std=[[6.5  7.68]].

# %% [markdown]
# #### fictitious play (FP)

# %%
## useful utility functions
def init_fp_models(learn_iter,header,curr_iter=0):
    policy_models = []
    for p_ in range(4):
        policy_model = CFRModel(save_dir='model/',deck_size=deck_size)
        policy_model.learn_iter = learn_iter
        policy_model.train_target_flag = 'p'
        policy_models.append(policy_model)
    agg_policy_model = CFRModel(save_dir='model/',deck_size=deck_size)
    agg_policy_model.learn_iter = learn_iter * 2
    agg_policy_model.train_target_flag = 'p'
    save_fp_models(policy_models,agg_policy_model,header,iter_=curr_iter)
    return policy_models,agg_policy_model

def save_fp_models(policy_models,agg_policy_model,header,iter_):
    for p_ in range(4):
        policy_models[p_].save('{}/p{}-{}'.format(header,p_,iter_))
    agg_policy_model.save('{}/agg-{}'.format(header,iter_))

def load_fp_models(header,iter_):
    policy_models = []
    for p_ in range(4):
        policy_model = CFRModel(save_dir='model/',deck_size=deck_size)
        policy_model.partial_restore('{}/p{}-{}'.format(header,p_,iter_))
        policy_models.append(policy_model)
    agg_policy_model = CFRModel(save_dir='model/',deck_size=deck_size)
    agg_policy_model.partial_restore('{}/agg-{}'.format(header,iter_))
    return policy_models,agg_policy_model

def load_fp_agent(header,iter_,infer_flag=True):
    policy_models,agg_policy_model = \
            load_fp_models(header,iter_)
    agent = FPAgent(agg_policy_model,agg_policy_model)
    agent.infer_flag = infer_flag
    agent.status_flag = 'infer'
    agent.sample_collect_flag = False
    return agent

# %%
version = 1
header = 'fp-v{}'.format(version)

# %%
## initialize model
N_iter_train = 500
curr_iter = 0
policy_models,agg_policy_model = init_fp_models(N_iter_train,header,curr_iter)

# %%
## train model using FP
agents = []
for p_ in range(4):
    agent = FPAgent(policy_models[p_],agg_policy_model)
    agents.append(agent)

tt = time.time()
N_iter_inner = 2000
eval_freq = 1
for iter_outer in range(20):
    for agent in agents:
        agent.update_train_meta()
        
    for p_ in range(4):
        for agent in agents:
            agent.sample_collect_flag = False
            agent.status_flag = 'infer'
        agents[p_].sample_collect_flag = True
        
        ## BR
        q_model_tmp = QModel(save_dir='model/',deck_size=deck_size)
        q_model_tmp.learn_iter = 1
        agents[p_].q_model = q_model_tmp
        agents[p_].status_flag = 'BR'
        run_games(N_iter=N_iter_inner,agents=agents,if_train=True,
                  models=[q_model_tmp],state_generator=StateExtendV2)
        
        ## avg
        agents[p_].status_flag = 'avg'
        run_games(N_iter=500,agents=agents,if_train=False,state_generator=StateExtendV2)
        
        policy_models[p_].learn()
    agg_policy_model.learn()
    
    save_fp_models(policy_models,agg_policy_model,header,curr_iter+(iter_outer+1)*N_iter_inner)
    print('{}:{:.2f}'.format(iter_outer+1,time.time() - tt))
    
    if (iter_outer+1) % eval_freq == 0 and iter_outer > 0:
        ## do some evaluation
        a_ai_1 = load_fp_agent(header,curr_iter+(iter_outer+1-eval_freq)*N_iter_inner)
        a_ai_2 = load_fp_agent(header,curr_iter+(iter_outer+1)*N_iter_inner)
        a_base = Agent()
        
        out_str = compare_agents(a_base,a_ai_1,a_ai_2,N_iter_loops=100,N_iter_games=100,
                    compare_first_base_flag=True,compare_both_flag=True)
        print('{}, {}'.format(iter_outer,out_str))
# Out:
# 1:3841.25
# 2:7587.94
# INFO:tensorflow:Restoring parameters from model/fp-v1/p0-2000/model
# INFO:tensorflow:Restoring parameters from model/fp-v1/p1-2000/model
# INFO:tensorflow:Restoring parameters from model/fp-v1/p2-2000/model
# INFO:tensorflow:Restoring parameters from model/fp-v1/p3-2000/model
# INFO:tensorflow:Restoring parameters from model/fp-v1/agg-2000/model
# INFO:tensorflow:Restoring parameters from model/fp-v1/p0-4000/model
# INFO:tensorflow:Restoring parameters from model/fp-v1/p1-4000/model
# INFO:tensorflow:Restoring parameters from model/fp-v1/p2-4000/model
# INFO:tensorflow:Restoring parameters from model/fp-v1/p3-4000/model
# INFO:tensorflow:Restoring parameters from model/fp-v1/agg-4000/model
# 1, time: 783.93. eval results: mean=[[-5.29 -6.2 ]
#  [-8.38 -8.72]], std=[[6.47 6.96]
#  [6.18 6.41]].
# 3:12275.24
# INFO:tensorflow:Restoring parameters from model/fp-v1/p0-4000/model
# INFO:tensorflow:Restoring parameters from model/fp-v1/p1-4000/model
# INFO:tensorflow:Restoring parameters from model/fp-v1/p2-4000/model
# INFO:tensorflow:Restoring parameters from model/fp-v1/p3-4000/model
# INFO:tensorflow:Restoring parameters from model/fp-v1/agg-4000/model
# INFO:tensorflow:Restoring parameters from model/fp-v1/p0-6000/model
# INFO:tensorflow:Restoring parameters from model/fp-v1/p1-6000/model
# INFO:tensorflow:Restoring parameters from model/fp-v1/p2-6000/model
# INFO:tensorflow:Restoring parameters from model/fp-v1/p3-6000/model
# INFO:tensorflow:Restoring parameters from model/fp-v1/agg-6000/model
# 2, time: 790.39. eval results: mean=[[-8.47 -8.28]
#  [-8.08 -9.76]], std=[[7.89 6.13]
#  [6.95 6.91]].
# 4:16957.98
# INFO:tensorflow:Restoring parameters from model/fp-v1/p0-6000/model
# INFO:tensorflow:Restoring parameters from model/fp-v1/p1-6000/model
# INFO:tensorflow:Restoring parameters from model/fp-v1/p2-6000/model
# INFO:tensorflow:Restoring parameters from model/fp-v1/p3-6000/model
# INFO:tensorflow:Restoring parameters from model/fp-v1/agg-6000/model
# INFO:tensorflow:Restoring parameters from model/fp-v1/p0-8000/model
# INFO:tensorflow:Restoring parameters from model/fp-v1/p1-8000/model
# INFO:tensorflow:Restoring parameters from model/fp-v1/p2-8000/model
# INFO:tensorflow:Restoring parameters from model/fp-v1/p3-8000/model
# INFO:tensorflow:Restoring parameters from model/fp-v1/agg-8000/model
# 3, time: 790.30. eval results: mean=[[-6.81 -8.28]
#  [-9.94 -8.92]], std=[[7.63 7.82]
#  [7.49 6.56]].
# 5:21671.71
# INFO:tensorflow:Restoring parameters from model/fp-v1/p0-8000/model
# INFO:tensorflow:Restoring parameters from model/fp-v1/p1-8000/model
# INFO:tensorflow:Restoring parameters from model/fp-v1/p2-8000/model
# INFO:tensorflow:Restoring parameters from model/fp-v1/p3-8000/model
# INFO:tensorflow:Restoring parameters from model/fp-v1/agg-8000/model
# INFO:tensorflow:Restoring parameters from model/fp-v1/p0-10000/model
# INFO:tensorflow:Restoring parameters from model/fp-v1/p1-10000/model
# INFO:tensorflow:Restoring parameters from model/fp-v1/p2-10000/model
# INFO:tensorflow:Restoring parameters from model/fp-v1/p3-10000/model
# INFO:tensorflow:Restoring parameters from model/fp-v1/agg-10000/model
# 4, time: 804.06. eval results: mean=[[-5.33 -7.03]
#  [-6.95 -7.63]], std=[[7.32 7.2 ]
#  [7.82 7.13]].
# 6:26422.61
# INFO:tensorflow:Restoring parameters from model/fp-v1/p0-10000/model
# INFO:tensorflow:Restoring parameters from model/fp-v1/p1-10000/model
# INFO:tensorflow:Restoring parameters from model/fp-v1/p2-10000/model
# INFO:tensorflow:Restoring parameters from model/fp-v1/p3-10000/model
# INFO:tensorflow:Restoring parameters from model/fp-v1/agg-10000/model
# INFO:tensorflow:Restoring parameters from model/fp-v1/p0-12000/model
# INFO:tensorflow:Restoring parameters from model/fp-v1/p1-12000/model
# INFO:tensorflow:Restoring parameters from model/fp-v1/p2-12000/model
# INFO:tensorflow:Restoring parameters from model/fp-v1/p3-12000/model
# INFO:tensorflow:Restoring parameters from model/fp-v1/agg-12000/model
# 5, time: 785.54. eval results: mean=[[-6.35 -6.6 ]
#  [-6.69 -6.64]], std=[[7.88 7.13]
#  [7.4  7.61]].
# 7:31210.22
# INFO:tensorflow:Restoring parameters from model/fp-v1/p0-12000/model
# INFO:tensorflow:Restoring parameters from model/fp-v1/p1-12000/model
# INFO:tensorflow:Restoring parameters from model/fp-v1/p2-12000/model
# INFO:tensorflow:Restoring parameters from model/fp-v1/p3-12000/model
# INFO:tensorflow:Restoring parameters from model/fp-v1/agg-12000/model
# INFO:tensorflow:Restoring parameters from model/fp-v1/p0-14000/model
# INFO:tensorflow:Restoring parameters from model/fp-v1/p1-14000/model
# INFO:tensorflow:Restoring parameters from model/fp-v1/p2-14000/model
# INFO:tensorflow:Restoring parameters from model/fp-v1/p3-14000/model
# INFO:tensorflow:Restoring parameters from model/fp-v1/agg-14000/model
# 6, time: 781.91. eval results: mean=[[-7.52 -7.37]
#  [-7.43 -7.69]], std=[[6.93 7.54]
#  [7.51 7.31]].
# 8:35980.35
# INFO:tensorflow:Restoring parameters from model/fp-v1/p0-14000/model
# INFO:tensorflow:Restoring parameters from model/fp-v1/p1-14000/model
# INFO:tensorflow:Restoring parameters from model/fp-v1/p2-14000/model
# INFO:tensorflow:Restoring parameters from model/fp-v1/p3-14000/model
# INFO:tensorflow:Restoring parameters from model/fp-v1/agg-14000/model
# INFO:tensorflow:Restoring parameters from model/fp-v1/p0-16000/model
# INFO:tensorflow:Restoring parameters from model/fp-v1/p1-16000/model
# INFO:tensorflow:Restoring parameters from model/fp-v1/p2-16000/model
# INFO:tensorflow:Restoring parameters from model/fp-v1/p3-16000/model
# INFO:tensorflow:Restoring parameters from model/fp-v1/agg-16000/model
# 7, time: 792.23. eval results: mean=[[-6.7  -6.69]
#  [-7.9  -7.6 ]], std=[[6.28 7.97]
#  [6.88 6.48]].
# 9:40801.73
# INFO:tensorflow:Restoring parameters from model/fp-v1/p0-16000/model
# INFO:tensorflow:Restoring parameters from model/fp-v1/p1-16000/model
# INFO:tensorflow:Restoring parameters from model/fp-v1/p2-16000/model
# INFO:tensorflow:Restoring parameters from model/fp-v1/p3-16000/model
# INFO:tensorflow:Restoring parameters from model/fp-v1/agg-16000/model
# INFO:tensorflow:Restoring parameters from model/fp-v1/p0-18000/model
# INFO:tensorflow:Restoring parameters from model/fp-v1/p1-18000/model
# INFO:tensorflow:Restoring parameters from model/fp-v1/p2-18000/model
# INFO:tensorflow:Restoring parameters from model/fp-v1/p3-18000/model
# INFO:tensorflow:Restoring parameters from model/fp-v1/agg-18000/model
# 8, time: 792.82. eval results: mean=[[-6.38 -5.96]
#  [-6.31 -7.33]], std=[[8.14 6.88]
#  [7.44 7.42]].
# 10:53809.19
# INFO:tensorflow:Restoring parameters from model/fp-v1/p0-18000/model
# INFO:tensorflow:Restoring parameters from model/fp-v1/p1-18000/model
# INFO:tensorflow:Restoring parameters from model/fp-v1/p2-18000/model
# INFO:tensorflow:Restoring parameters from model/fp-v1/p3-18000/model
# INFO:tensorflow:Restoring parameters from model/fp-v1/agg-18000/model
# INFO:tensorflow:Restoring parameters from model/fp-v1/p0-20000/model
# INFO:tensorflow:Restoring parameters from model/fp-v1/p1-20000/model
# INFO:tensorflow:Restoring parameters from model/fp-v1/p2-20000/model
# INFO:tensorflow:Restoring parameters from model/fp-v1/p3-20000/model
# INFO:tensorflow:Restoring parameters from model/fp-v1/agg-20000/model
# 9, time: 788.65. eval results: mean=[[-6.18 -5.89]
#  [-7.12 -7.01]], std=[[6.84 7.89]
#  [7.57 7.14]].
# 11:58956.71
# INFO:tensorflow:Restoring parameters from model/fp-v1/p0-20000/model
# INFO:tensorflow:Restoring parameters from model/fp-v1/p1-20000/model
# INFO:tensorflow:Restoring parameters from model/fp-v1/p2-20000/model
# INFO:tensorflow:Restoring parameters from model/fp-v1/p3-20000/model
# INFO:tensorflow:Restoring parameters from model/fp-v1/agg-20000/model
# INFO:tensorflow:Restoring parameters from model/fp-v1/p0-22000/model
# INFO:tensorflow:Restoring parameters from model/fp-v1/p1-22000/model
# INFO:tensorflow:Restoring parameters from model/fp-v1/p2-22000/model
# INFO:tensorflow:Restoring parameters from model/fp-v1/p3-22000/model
# INFO:tensorflow:Restoring parameters from model/fp-v1/agg-22000/model
# 10, time: 788.33. eval results: mean=[[-5.93 -6.47]
#  [-6.62 -6.78]], std=[[7.46 6.54]
#  [7.16 7.13]].
# 12:64264.48
# INFO:tensorflow:Restoring parameters from model/fp-v1/p0-22000/model
# INFO:tensorflow:Restoring parameters from model/fp-v1/p1-22000/model
# INFO:tensorflow:Restoring parameters from model/fp-v1/p2-22000/model
# INFO:tensorflow:Restoring parameters from model/fp-v1/p3-22000/model
# INFO:tensorflow:Restoring parameters from model/fp-v1/agg-22000/model
# INFO:tensorflow:Restoring parameters from model/fp-v1/p0-24000/model
# INFO:tensorflow:Restoring parameters from model/fp-v1/p1-24000/model
# INFO:tensorflow:Restoring parameters from model/fp-v1/p2-24000/model
# INFO:tensorflow:Restoring parameters from model/fp-v1/p3-24000/model
# INFO:tensorflow:Restoring parameters from model/fp-v1/agg-24000/model
# 11, time: 812.29. eval results: mean=[[-6.17 -6.29]
#  [-7.02 -5.75]], std=[[7.49 7.91]
#  [6.14 7.01]].
# 13:69509.62
# INFO:tensorflow:Restoring parameters from model/fp-v1/p0-24000/model
# INFO:tensorflow:Restoring parameters from model/fp-v1/p1-24000/model
# INFO:tensorflow:Restoring parameters from model/fp-v1/p2-24000/model
# INFO:tensorflow:Restoring parameters from model/fp-v1/p3-24000/model
# INFO:tensorflow:Restoring parameters from model/fp-v1/agg-24000/model
# INFO:tensorflow:Restoring parameters from model/fp-v1/p0-26000/model
# INFO:tensorflow:Restoring parameters from model/fp-v1/p1-26000/model
# INFO:tensorflow:Restoring parameters from model/fp-v1/p2-26000/model
# INFO:tensorflow:Restoring parameters from model/fp-v1/p3-26000/model
# INFO:tensorflow:Restoring parameters from model/fp-v1/agg-26000/model
# 12, time: 811.17. eval results: mean=[[-7.3  -5.39]
#  [-5.39 -6.83]], std=[[7.92 7.01]
#  [7.44 7.02]].
# 14:74653.88
# INFO:tensorflow:Restoring parameters from model/fp-v1/p0-26000/model
# INFO:tensorflow:Restoring parameters from model/fp-v1/p1-26000/model
# INFO:tensorflow:Restoring parameters from model/fp-v1/p2-26000/model
# INFO:tensorflow:Restoring parameters from model/fp-v1/p3-26000/model
# INFO:tensorflow:Restoring parameters from model/fp-v1/agg-26000/model
# INFO:tensorflow:Restoring parameters from model/fp-v1/p0-28000/model
# INFO:tensorflow:Restoring parameters from model/fp-v1/p1-28000/model
# INFO:tensorflow:Restoring parameters from model/fp-v1/p2-28000/model
# INFO:tensorflow:Restoring parameters from model/fp-v1/p3-28000/model
# INFO:tensorflow:Restoring parameters from model/fp-v1/agg-28000/model
# 13, time: 815.21. eval results: mean=[[-5.28 -6.85]
#  [-6.57 -7.04]], std=[[7.59 8.06]
#  [6.94 7.36]].
# 15:79867.85
# INFO:tensorflow:Restoring parameters from model/fp-v1/p0-28000/model
# INFO:tensorflow:Restoring parameters from model/fp-v1/p1-28000/model
# INFO:tensorflow:Restoring parameters from model/fp-v1/p2-28000/model
# INFO:tensorflow:Restoring parameters from model/fp-v1/p3-28000/model
# INFO:tensorflow:Restoring parameters from model/fp-v1/agg-28000/model
# INFO:tensorflow:Restoring parameters from model/fp-v1/p0-30000/model
# INFO:tensorflow:Restoring parameters from model/fp-v1/p1-30000/model
# INFO:tensorflow:Restoring parameters from model/fp-v1/p2-30000/model
# INFO:tensorflow:Restoring parameters from model/fp-v1/p3-30000/model
# INFO:tensorflow:Restoring parameters from model/fp-v1/agg-30000/model
# 14, time: 800.06. eval results: mean=[[-5.49 -4.92]
#  [-6.52 -5.04]], std=[[6.72 7.84]
#  [7.66 6.86]].
# 16:84956.33
# INFO:tensorflow:Restoring parameters from model/fp-v1/p0-30000/model
# INFO:tensorflow:Restoring parameters from model/fp-v1/p1-30000/model
# INFO:tensorflow:Restoring parameters from model/fp-v1/p2-30000/model
# INFO:tensorflow:Restoring parameters from model/fp-v1/p3-30000/model
# INFO:tensorflow:Restoring parameters from model/fp-v1/agg-30000/model
# INFO:tensorflow:Restoring parameters from model/fp-v1/p0-32000/model
# INFO:tensorflow:Restoring parameters from model/fp-v1/p1-32000/model
# INFO:tensorflow:Restoring parameters from model/fp-v1/p2-32000/model
# INFO:tensorflow:Restoring parameters from model/fp-v1/p3-32000/model
# INFO:tensorflow:Restoring parameters from model/fp-v1/agg-32000/model
# 15, time: 853.00. eval results: mean=[[-4.88 -5.66]
#  [-6.41 -6.97]], std=[[6.53 7.42]
#  [6.96 7.36]].
# 17:90158.92
# INFO:tensorflow:Restoring parameters from model/fp-v1/p0-32000/model
# INFO:tensorflow:Restoring parameters from model/fp-v1/p1-32000/model
# INFO:tensorflow:Restoring parameters from model/fp-v1/p2-32000/model
# INFO:tensorflow:Restoring parameters from model/fp-v1/p3-32000/model
# INFO:tensorflow:Restoring parameters from model/fp-v1/agg-32000/model
# INFO:tensorflow:Restoring parameters from model/fp-v1/p0-34000/model
# INFO:tensorflow:Restoring parameters from model/fp-v1/p1-34000/model
# INFO:tensorflow:Restoring parameters from model/fp-v1/p2-34000/model
# INFO:tensorflow:Restoring parameters from model/fp-v1/p3-34000/model
# INFO:tensorflow:Restoring parameters from model/fp-v1/agg-34000/model
# 16, time: 798.79. eval results: mean=[[-4.77 -5.91]
#  [-6.78 -6.77]], std=[[7.31 7.35]
#  [5.95 7.59]].
# 18:95177.35
# INFO:tensorflow:Restoring parameters from model/fp-v1/p0-34000/model
# INFO:tensorflow:Restoring parameters from model/fp-v1/p1-34000/model
# INFO:tensorflow:Restoring parameters from model/fp-v1/p2-34000/model
# INFO:tensorflow:Restoring parameters from model/fp-v1/p3-34000/model
# INFO:tensorflow:Restoring parameters from model/fp-v1/agg-34000/model
# INFO:tensorflow:Restoring parameters from model/fp-v1/p0-36000/model
# INFO:tensorflow:Restoring parameters from model/fp-v1/p1-36000/model
# INFO:tensorflow:Restoring parameters from model/fp-v1/p2-36000/model
# INFO:tensorflow:Restoring parameters from model/fp-v1/p3-36000/model
# INFO:tensorflow:Restoring parameters from model/fp-v1/agg-36000/model
# 17, time: 790.19. eval results: mean=[[-5.45 -7.14]
#  [-7.16 -5.53]], std=[[7.28 6.61]
#  [7.55 7.05]].
# 19:100141.50
# INFO:tensorflow:Restoring parameters from model/fp-v1/p0-36000/model
# INFO:tensorflow:Restoring parameters from model/fp-v1/p1-36000/model
# INFO:tensorflow:Restoring parameters from model/fp-v1/p2-36000/model
# INFO:tensorflow:Restoring parameters from model/fp-v1/p3-36000/model
# INFO:tensorflow:Restoring parameters from model/fp-v1/agg-36000/model
# INFO:tensorflow:Restoring parameters from model/fp-v1/p0-38000/model
# INFO:tensorflow:Restoring parameters from model/fp-v1/p1-38000/model
# INFO:tensorflow:Restoring parameters from model/fp-v1/p2-38000/model
# INFO:tensorflow:Restoring parameters from model/fp-v1/p3-38000/model
# INFO:tensorflow:Restoring parameters from model/fp-v1/agg-38000/model
# 18, time: 823.26. eval results: mean=[[-5.43 -8.28]
#  [-6.99 -5.83]], std=[[7.45 6.44]
#  [7.73 7.9 ]].
# 20:113156.09
# INFO:tensorflow:Restoring parameters from model/fp-v1/p0-38000/model
# INFO:tensorflow:Restoring parameters from model/fp-v1/p1-38000/model
# INFO:tensorflow:Restoring parameters from model/fp-v1/p2-38000/model
# INFO:tensorflow:Restoring parameters from model/fp-v1/p3-38000/model
# INFO:tensorflow:Restoring parameters from model/fp-v1/agg-38000/model
# INFO:tensorflow:Restoring parameters from model/fp-v1/p0-40000/model
# INFO:tensorflow:Restoring parameters from model/fp-v1/p1-40000/model
# INFO:tensorflow:Restoring parameters from model/fp-v1/p2-40000/model
# INFO:tensorflow:Restoring parameters from model/fp-v1/p3-40000/model
# INFO:tensorflow:Restoring parameters from model/fp-v1/agg-40000/model
# 19, time: 800.48. eval results: mean=[[-5.78 -6.37]
#  [-6.45 -7.21]], std=[[6.23 6.38]
#  [7.49 6.94]].

# %%
## do some final evaluation
a_ai_1 = load_fp_agent(header,0)
a_ai_2 = load_fp_agent(header,40000)
a_base = Agent()

out_str = compare_agents(a_base,a_ai_1,a_ai_2,N_iter_loops=100,N_iter_games=100,compare_both_flag=True)
print(out_str)
# Out:
# INFO:tensorflow:Restoring parameters from model/fp-v1/p0-0/model
# INFO:tensorflow:Restoring parameters from model/fp-v1/p1-0/model
# INFO:tensorflow:Restoring parameters from model/fp-v1/p2-0/model
# INFO:tensorflow:Restoring parameters from model/fp-v1/p3-0/model
# INFO:tensorflow:Restoring parameters from model/fp-v1/agg-0/model
# INFO:tensorflow:Restoring parameters from model/fp-v1/p0-40000/model
# INFO:tensorflow:Restoring parameters from model/fp-v1/p1-40000/model
# INFO:tensorflow:Restoring parameters from model/fp-v1/p2-40000/model
# INFO:tensorflow:Restoring parameters from model/fp-v1/p3-40000/model
# INFO:tensorflow:Restoring parameters from model/fp-v1/agg-40000/model
# time: 508.81. eval results: mean=[[-5.5  -7.26]], std=[[7.54 6.56]].
